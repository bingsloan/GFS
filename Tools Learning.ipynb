# %% [markdown]
# # 编程重要工具

# %% [markdown]
# ## Anaconda

# %% [markdown]
# https://www.bilibili.com/video/av33976385/  7天入门python数据分析(JupyterNotebook/numpy/pandas/matplotlib)

# %% [markdown]
# ### Jupyter notebook

# %% [markdown]
# #### 目录生成

# %% [markdown]
# conda install -c conda-forge jupyter_contrib_nbextensions

# %% [markdown]
# 运行Jupyter Notebook, 在打开的Notebook界面里, 你会发现多了一个Nbextensions,点击这个tab, 会有如下界面,勾选Table of Contents (有的版本是toc2). 然后创建或者打开一个Jupter Notebook,在Notebook上面选项（在键盘图标右侧）多了一个生成目录图标。

# %% [markdown]
# ![%E6%97%A0%E6%A0%87%E9%A2%98.png](attachment:%E6%97%A0%E6%A0%87%E9%A2%98.png)

# %% [markdown]
# ## Github

# %% [markdown]
# www.runoob.com/w3cnote/git-guide.html

# %% [markdown]
# ### git

# %% [markdown]
# 添加远程库  https://www.liaoxuefeng.com/wiki/0013739516305929606dd18361248578c67b8067c8c017b000/0013752340242354807e192f02a44359908df8a5643103a000

# %% [markdown]
# git原理图解 https://www.cnblogs.com/cb0327/p/5066685.html

# %% [markdown]
# 深入理解学习Git工作流  https://segmentfault.com/a/1190000002918123

# %% [markdown]
# ### bash

# %% [markdown]
# ### vim

# %% [markdown]
# ### ssh
